# %% [markdown]
# <a href="https://colab.research.google.com/github/MK316/Spring2024/blob/main/Engpro/Lesson11.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 📙 **Lesson 11. Accents in English**

# %% [markdown]
# # Setting

# %%
#@markdown 🔄 setup
# %%capture
# !pip install gTTS
from gtts import gTTS
from IPython.display import Audio

gtts

# %% [markdown]
# # **[1] _What do you think an accent is?_**

# %%
#@markdown English accent: Type text
Spelling = "1" #@param = [1, 2, 3, 4, 5]
Language = "ko" #@param = ["en","fr","zh-CN","es", "ko", "ja"]
Dialect = "com.au" #@param = ["com.au","co.uk","us","ca","co.in","ie", "co.za"]
pn = int(Spelling) -1

words = input("Type text: ")

wlist = words
txt = "I'm learning English like you. Let's practice together. " + " " + wlist

if Language == "en":
  def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = Dialect,
                    slow = False)
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")
else:
  def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                       lang = Language, slow = False)
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")

tts(txt)
Audio("E-audio.mp3", autoplay = True)
# Out:
# Type text: Today is Friday.
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # **[2] Understanding accents**

# %%
#@markdown tts(txt) {English}: In addition to word stress,...
def tts(txt):
    text_to_say = txt
    gtts_object = gTTS(text = text_to_say,
                     lang = "en", tld = "us",
                    slow = False)
    gtts_object.save("E-audio.mp3")
    return Audio("E-audio.mp3")

text = """
In addition to word stress, which is assigned to a syllable, English words can receive accents within a sentence. This results in greater emphasis when stress and accent are combined. For example, stressed syllables are more emphasized than unstressed ones, and stressed syllables in accented words are stronger and longer than those in unaccented words.
"""

tts(text)
print(text)
display(Audio("E-audio.mp3"))

text="My younger brother ate ten chocolate cookies"
tts(text)
print(text)
display(Audio("E-audio.mp3"))
# Out:
# In addition to word stress, which is assigned to a syllable, English words can receive accents within a sentence. This results in greater emphasis when stress and accent are combined. For example, stressed syllables are more emphasized than unstressed ones, and stressed syllables in accented words are stronger and longer than those in unaccented words.
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
# My younger brother ate ten chocolate cookies
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
#@markdown Page 65. [1] to [3] descriptions
text=[
"We're in page 65, and I'll be explaining word accents in English."
"Number one. Understanding how pitch accents work in English can significantly enhance your comprehension and pronunciation skills. Let's delve into how new information within a sentence is often highlighted using a higher pitch.",
"Consider the introduction: 'My name is Jane Smith.' When introducing yourself, the new and important information here is 'Jane Smith.' To signify its importance, we naturally raise the pitch on 'Jane,' marking it with a high pitch accent, symbolized as 'High star.' This contrast can change the meaning or focus of a sentence. For example, if we were to emphasize 'My' instead, by applying a high pitch there, it shifts the focus, suggesting perhaps a contrast or correction to a previous statement, as in correcting someone's mistaken assumption about your name. Conversely, a lower pitch on 'Jane' would make the sentence sound flat and less engaging, lacking the indication that 'Jane Smith' is the key piece of new information.",
"Number two. In English, the placement of emphasis within a sentence is crucial for conveying meaning and structure. A fundamental pattern in English speech is placing the most emphasis on the final key word of a sentence.",
"A. Let's analyze a few examples: First, consider the sentence 'Steve is my cousin.' Here, 'cousin' is the final key word, carrying the most significant piece of information about Steve. By emphasizing 'cousin,' we clarify the relationship, making it the focal point of the sentence.",
"B. Next, 'He is at the store.' In this sentence, 'store' receives the most emphasis. It's the key location we're talking about, where 'He' is currently located. The emphasis on 'store' makes it clear that this is the crucial piece of new information being conveyed.",
"C. Lastly, take 'Today is Saturday.' The emphasis falls on 'Saturday,' the most critical piece of information, telling us exactly what day today is. By emphasizing 'Saturday,' we effectively communicate the specific day of the week, marking it as the sentence's focus."
"Through these examples, it's evident that emphasizing the final key word helps convey the main point more effectively, guiding the listener's understanding of what is deemed most important in the sentence."
"Number three. Function words in English are not accented unless they are intentionally emphasized. Function words include articles, prepositions, pronouns, conjunctions, and helping verbs",
"Here are some examples. One. You'll see him again sooner or later. Two. The lecture will start in a moment. Three. To tell the truth, I was quite nervous before giving the presentation. Four. I want to be a singer."
]

for i in range(0,10):
  txt = text[i]
  tts(txt)
  print(txt)
  display(Audio("E-audio.mp3"))
  print("*"*30)

# %% [markdown]
# ---
# The end
